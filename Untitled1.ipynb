# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas

# %%
#!pip list

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#!pip install openpyxl

# %%
df = pd.read_excel('C:\\Users\\Andrey\\Documents\\Книга18.xlsx', sheet_name='Лист1')

# %%
df
# Out:
#     Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   \
# 0                        9.00     1                                   1
# 1                       22.00     1                                   1
# 2                       13.00     1                                   1
# 3                       18.00     1                                   1
# 4                       25.00     1                                   1
# ..                        ...   ...                                 ...
# 64                      40.78     1                                   3
# 65                      21.50     1                                   2
# 66                     115.23     1                                   1
# 67                      34.80     1                                   2
# 68                      22.00     1                                   2
#
#             Тип  Рейтинг в гуглі  Количество чеков  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 16 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Торговельна площа, кв. м.           69 non-null     float64
#  1   Этаж                                69 non-null     int64
#  2   Количество сотрудников в магазине   69 non-null     int64
#  3   Тип                                 69 non-null     object
#  4   Рейтинг в гуглі                     69 non-null     float64
#  5   Количество чеков                    69 non-null     float64
#  6   Среднее количество единиц в чеке    62 non-null     float64
#  7   Автомобілів в день                  64 non-null     float64
#  8   Середній дохід населення            64 non-null     float64
#  9   Транзитна зупинка міжміського ГТ    69 non-null     int64
#  10  Зупинка ГТ                          69 non-null     int64
# ...

# %%
df['Торговельна площа, кв. м.'].plot(kind = 'hist')   
#Большую долю занимают торговые площади равны 20.
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Рейтинг в гуглі'].plot(kind = 'hist')
 #Видим что для нашей выборки оценка 2 - нетипично
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Количество чеков'].plot(kind = 'hist')
 #Видим что для нашей выборки 7000 чеков - нетипично.
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Среднее количество единиц в чеке'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Середній дохід населення'].plot(kind = 'hist')
#Видим что для нашей выборки доход менее 8000 - нетипично.
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dfr = df.drop(['Этаж'], axis='columns', inplace=False)
dfr.shape
# Out:
# (69, 15)

# %%
df.describe()
# Out:
#        Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   \
# count                  69.000000  69.0                           69.000000
# mean                   34.872145   1.0                            1.869565
# std                    21.704293   0.0                            0.838645
# min                     4.000000   1.0                            1.000000
# 25%                    22.000000   1.0                            1.000000
# 50%                    27.500000   1.0                            2.000000
# 75%                    41.000000   1.0                            2.000000
# max                   119.300000   1.0                            4.000000
#
#        Рейтинг в гуглі  Количество чеков  Среднее количество единиц в чеке  \
# count        69.000000         69.000000                         62.000000
# mean          3.810145       3021.576882                          1.896290
# ...

# %%
#!pip install sklearn

# %%
dfm = df

from sklearn.impute import SimpleImputer

power_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
dfm[['Среднее количество единиц в чеке']] = power_mean.fit_transform(dfm[['Среднее количество единиц в чеке']]).round()
power_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
dfm[['Автомобілів в день']] = power_mean.fit_transform(dfm[['Автомобілів в день']]).round()
power_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
dfm[['Середній дохід населення']] = power_mean.fit_transform(dfm[['Середній дохід населення']]).round()

# %%
df.describe()
# Out:
#        Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   \
# count                  69.000000  69.0                           69.000000
# mean                   34.872145   1.0                            1.869565
# std                    21.704293   0.0                            0.838645
# min                     4.000000   1.0                            1.000000
# 25%                    22.000000   1.0                            1.000000
# 50%                    27.500000   1.0                            2.000000
# 75%                    41.000000   1.0                            2.000000
# max                   119.300000   1.0                            4.000000
#
#        Рейтинг в гуглі  Количество чеков  Среднее количество единиц в чеке  \
# count        69.000000         69.000000                         69.000000
# mean          3.810145       3021.576882                          1.971014
# ...

# %%
df[['Середній дохід населення', 'Среднее количество единиц в чеке']] = np.log(df[['Середній дохід населення', 'Среднее количество единиц в чеке']])

import seaborn as sns
sns.set()
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-be5d3179c802> in <module>
#       3 import seaborn as sns
#       4 sns.set()
# ----> 5 sns.pairplot(df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2017     diag_kws.setdefault("legend", False)
#    2018     if diag_kind == "hist":
# -> 2019         grid.map_diag(histplot, **diag_kws)
#    2020     elif diag_kind == "kde":
#    2021         diag_kws.setdefault("fill", True)
#
# ...

# %%
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std() 
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std() 
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %%
df = outliers(df)
df.describe()
# Out:
#        Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   \
# count                  69.000000  69.0                           69.000000
# mean                   34.371276   1.0                            1.869565
# std                    19.893026   0.0                            0.838645
# min                     4.000000   1.0                            1.000000
# 25%                    22.000000   1.0                            1.000000
# 50%                    27.500000   1.0                            2.000000
# 75%                    41.000000   1.0                            2.000000
# max                    99.985025   1.0                            4.000000
#
#        Рейтинг в гуглі  Количество чеков  Среднее количество единиц в чеке  \
# count        69.000000         69.000000                         69.000000
# mean          3.810145       3021.576882                          0.676915
# ...

# %%
df3 = dfm[['Тип']]
info = []
for column in df3.columns:
        vals = {"col": column,
                "nunique": df3[column].nunique(),
                "unique": df3[column].unique(),
                "type": df3[column].dtype
               }
        info.append(vals)
pd.DataFrame(info).sort_values(by = "col", ascending = False)
# Out:
#    col  nunique                                             unique    type
# 0  Тип        5  [Соціальний, Стандартний, Преміальний, Стандар...  object

# %%
fm = {'Соціальний':1, 'Стандарт':2, 'Преміальний':3, 'Стандарт Плюс':4, 'Соціальний Плюс':5}
df['Тип'] = df['Тип'].map(fm)
df
# Out:
#     Торговельна площа, кв. м.  Этаж  Количество сотрудников в магазине   Тип  \
# 0                    9.000000     1                                   1  NaN
# 1                   22.000000     1                                   1  NaN
# 2                   13.000000     1                                   1  NaN
# 3                   18.000000     1                                   1  NaN
# 4                   25.000000     1                                   1  NaN
# ..                        ...   ...                                 ...  ...
# 64                  40.780000     1                                   3  NaN
# 65                  21.500000     1                                   2  NaN
# 66                  99.985025     1                                   1  NaN
# 67                  34.800000     1                                   2  NaN
# 68                  22.000000     1                                   2  NaN
#
# ...

# %%
import seaborn as sns
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %%
# Наибольшую корреляцию мы получаем в количестве сотрудников в магазине на  количество чеков. 
#Тогда получается, что нам необходимо построить однофакторную модельв которой будет зависимость количество сотрудников в магазине от количества чеков.

# %%
X = df.iloc[:, [True,False,True,False,True,True,True,False,True,True,True,True,True,True,False,False,]]
y = df['Количество сотрудников в магазине']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
X
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Количество сотрудников в магазине'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-80a0d52c722d> in <module>
# ...
